# %%
print(bool([]), bool([False]), bool(None))
# Out:
# False True False

# %%
from collections import deque
queue = deque([1, 3, "tanu"])
queue.appendleft(10)
print(queue)

# %%
ls = [1, 3]
ls.popleft()
print(ls)
