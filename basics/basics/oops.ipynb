# %%
def test(self, val):
    '''
    Only this portion is interepreted as docstring by python 
    For both class and function 
    '''
    '''
    1. Declaraton elsewhere in the function in triple quotes is considered comment and is ignored
    2. It is used to specify function or class details for proper input and output 
    3. Even acts as a blueprint for others while they are creating thier docstring
    '''
    
print(test.__doc__)
# Out:
#     Only this portion is interepreted as docstring by python
#     For both class and function

# %%
def test(self):
    a = 10
    b = 20
    '''This is a comment'''
    return a+b

print(test.__doc__) # empty returns None
# Out:
# None
