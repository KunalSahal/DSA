# %% [markdown]
# ## PEP8 (Python Enhancement Proposal)
#
#     1. Guido van Rossum, Barry Warsaw & Nick Coghian
#     2. Guidline for best practice regarding python coding

# %% [markdown]
# ## The Zen of Python
#
# import this return a poem by Tim Peters

# %% [markdown]
# <b> class Solution:
#     def getConcatenation(self, nums: List[int]) -> List[int]:
#         ans = nums*2 -> C Level Execution so much faster
#         return ans
# </b>
