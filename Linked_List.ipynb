# %%
class Node:
    def __init__(self, data):
        self.left = None
        self.data = data
        self.right = None

class LinkedList:
    def createList(data):
        return Node(10)
    
print("Enter data")
data = input()
print(data)
temp = LinkedList.createList(data)
# Out:
# Enter data
# 10
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 15
#      13 print(data)
#      14 temp = LinkedList.createList(data)
# ---> 15 print(temp.data)
#
# AttributeError: 'NoneType' object has no attribute 'data'
